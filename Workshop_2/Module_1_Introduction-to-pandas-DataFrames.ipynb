# %% [markdown]
# <a href="https://colab.research.google.com/github/OkitwiOpio/Recess_Internship/blob/main/Workshop_2/Module_1_Introduction-to-pandas-DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![banner](https://github.com/anopheles-genomic-surveillance/anopheles-genomic-surveillance.github.io/blob/master/docs/banner.jpg?raw=1)
#
# ***[Workshop 2](about) - Training course in data analysis for genomic surveillance of African malaria vectors***
#
# ---

# %% [markdown]
# # Module 1 - Introduction to pandas DataFrames
#
# **Theme: Tools & Technology**
#
# In this module we're going to take a closer look at a Python package called [pandas](https://pandas.pydata.org/), which is an essential part of our data analysis toolkit. We use pandas whenever we need to store, manipulate or analyse tables of data, also known as DataFrames. In this module we'll focus on using pandas to analyse genomic data, but it can be used to analyse any kind of data, so it's a very useful tool to have at your fingertips.

# %% [markdown]
# ## Learning objectives
#
# After this module you will be able to:
#
# * Explain what a DataFrame is
# * Access columns and rows from a DataFrame
# * Use indexes and queries
# * Write a DataFrame to a file
#
# Please note that this module will cover only a small part of the features that pandas provides - see the links at then end of this notebook if you'd like to go further.

# %% [markdown]
# ## Lecture

# %% [markdown]
# ### English

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/iIYftkvS0eM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/iIYftkvS0eM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### Français

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/RdyXA31iHz8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/RdyXA31iHz8" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Please note that the code in the cells below might differ from that shown in the video. This can happen because Python packages and their dependencies change due to updates, necessitating tweaks to the code.

# %% [markdown]
# ## Setup
#
# Let's install the `malariagen_data` package so we have easy access to some genomic data to demonstrate with. Pandas is already installed on colab.

# %%
# !pip install -q --no-warn-conflicts malariagen_data
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 33.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.5/302.5 kB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 60.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 78.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 21.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 82.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.8 MB/s eta 0:00:00
#   Building wheel for asciitree (setup.py) ... done

# %% [markdown]
# Now import the `malariagen_data` and `pandas` packages. Note that by convention we use `pd` as an abbreviation for `pandas`.

# %%
import malariagen_data
import pandas as pd
from google.colab import drive
import os

# %% [markdown]
# Set up access to the MalariaGEN Ag3.0 data resource.

# %%
ag3 = malariagen_data.Ag3()
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : gs://vo_agam_release/
# Data releases available : 3.0
# Results cache           : None
# Cohorts analysis        : 20230516
# AIM analysis            : 20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.12.0
# Client location         : Iowa, US
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %% [markdown]
# Mount your drive into the Google colab notebook filesystem.
# - This allows you to access and manipulate files stored in your Google Drive directly from your Colab notebook.

# %%
drive.mount('drive')
# Out:
# Mounted at drive

# %% [markdown]
# Create a results directory in your google drive as below.
# - `exist_ok = True` parameter ensures no error message is raised if the directory already exists. The directory will be created if it doesnot exist.

# %%
results_dir = "/content/drive/MyDrive/pandas_df"
os.makedirs(results_dir, exist_ok = True)

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %% [markdown]
# ## pandas DataFrames
#
# We use the pandas `DataFrame` class whenever we want to store and analyse data that can be structured as a table with rows and columns. Let's take a look at some examples of DataFrames that we met in the [first workshop](https://anopheles-genomic-surveillance.github.io/workshop-1/about.html) of this training course.

# %% [markdown]
# ### Example: sample metadata
#
# In [workshop 1, module 2](https://anopheles-genomic-surveillance.github.io/workshop-1/module-2-sample-metadata.html) we encountered the [sample_metadata()](https://malariagen.github.io/vector-data/ag3/api.html#sample-metadata) function. This function returns a DataFrame of sample metadata. Let's call this function and assign the result to the variable `df_samples`.

# %%
df_samples = ag3.sample_metadata(sample_sets="3.0")

# %% [markdown]
# Check what type of object we have received.

# %%
type(df_samples)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Inspect the data in the DataFrame by running a code cell containing just the name of the variable.

# %%
df_samples
# Out:
#      sample_id partner_sample_id      contributor    country location  year  \
# 0     AR0047-C            LUA047       Joao Pinto     Angola   Luanda  2009
# 1     AR0049-C            LUA049       Joao Pinto     Angola   Luanda  2009
# 2     AR0051-C            LUA051       Joao Pinto     Angola   Luanda  2009
# 3     AR0061-C            LUA061       Joao Pinto     Angola   Luanda  2009
# 4     AR0078-C            LUA078       Joao Pinto     Angola   Luanda  2009
# ...        ...               ...              ...        ...      ...   ...
# 3076  AD0494-C         80-2-o-16  Martin Donnelly  Lab Cross     LSTM    -1
# 3077  AD0495-C         80-2-o-17  Martin Donnelly  Lab Cross     LSTM    -1
# 3078  AD0496-C         80-2-o-18  Martin Donnelly  Lab Cross     LSTM    -1
# 3079  AD0497-C         80-2-o-19  Martin Donnelly  Lab Cross     LSTM    -1
# 3080  AD0498-C         80-2-o-20  Martin Donnelly  Lab Cross     LSTM    -1
#
#       month  latitude  longitude sex_call  ... admin1_name admin1_iso  \
# 0         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 1         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 2         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 3         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# 4         4    -8.884     13.302        F  ...      Luanda     AO-LUA
# ...     ...       ...        ...      ...  ...         ...        ...
# 3076     -1    53.409     -2.969        F  ...         NaN        NaN
# 3077     -1    53.409     -2.969        M  ...         NaN        NaN
# 3078     -1    53.409     -2.969        M  ...         NaN        NaN
# 3079     -1    53.409     -2.969        F  ...         NaN        NaN
# 3080     -1    53.409     -2.969        M  ...         NaN        NaN
#
#       admin2_name       taxon  cohort_admin1_year  cohort_admin1_month  \
# 0          Luanda    coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 1          Luanda    coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 2          Luanda    coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 3          Luanda    coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# 4          Luanda    coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04
# ...           ...         ...                 ...                  ...
# 3076          NaN  unassigned                 NaN                  NaN
# 3077          NaN  unassigned                 NaN                  NaN
# 3078          NaN  unassigned                 NaN                  NaN
# 3079          NaN  unassigned                 NaN                  NaN
# 3080          NaN  unassigned                 NaN                  NaN
#
#      cohort_admin1_quarter       cohort_admin2_year  \
# 0      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 1      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 2      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 3      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# 4      AO-LUA_colu_2009_Q2  AO-LUA_Luanda_colu_2009
# ...                    ...                      ...
# 3076                   NaN                      NaN
# 3077                   NaN                      NaN
# 3078                   NaN                      NaN
# 3079                   NaN                      NaN
# 3080                   NaN                      NaN
#
#              cohort_admin2_month       cohort_admin2_quarter
# 0     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 1     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 2     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 3     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# 4     AO-LUA_Luanda_colu_2009_04  AO-LUA_Luanda_colu_2009_Q2
# ...                          ...                         ...
# 3076                         NaN                         NaN
# 3077                         NaN                         NaN
# 3078                         NaN                         NaN
# 3079                         NaN                         NaN
# 3080                         NaN                         NaN
#
# [3081 rows x 30 columns]

# %% [markdown]
# There are 3,081 rows and 26 columns in this DataFrame. Each row provides data about a single mosquito DNA sample that has been sequenced by MalariaGEN. The columns provide data about those mosquitoes, such as the country and year in which the mosquito was originally collected.
#
# Note that the representation of the DataFrame above only shows some of the data - there are too many rows and columns to show all at once. The ellipsis character ("...") shows where some data have been hidden.

# %% [markdown]
# ### Example: genome annotations
#
# In [workshop 1, module 3](https://anopheles-genomic-surveillance.github.io/workshop-1/module-3-genome.html) we encountered the [geneset()](https://malariagen.github.io/vector-data/ag3/api.html#geneset) function. This function returns a DataFrame of genome annotations. Let's call the function and assign the result to the variable `df_geneset`.

# %%
df_geneset = ag3.geneset()
df_geneset
# Out:
#             contig      source             type   start       end  score  \
# 0               2L  VectorBase       chromosome       1  49364325    NaN
# 1               2L  VectorBase             gene  157348    186936    NaN
# 2               2L  VectorBase             mRNA  157348    181305    NaN
# 3               2L  VectorBase  three_prime_UTR  157348    157495    NaN
# 4               2L  VectorBase             exon  157348    157623    NaN
# ...            ...         ...              ...     ...       ...    ...
# 196140  Y_unplaced  VectorBase   five_prime_UTR   47932     48111    NaN
# 196141  Y_unplaced  VectorBase             exon   47932     48138    NaN
# 196142  Y_unplaced  VectorBase              CDS   48112     48138    NaN
# 196143  Y_unplaced  VectorBase             exon   48301     48385    NaN
# 196144  Y_unplaced  VectorBase              CDS   48301     48385    NaN
#
#        strand  phase             ID         Parent              Name  \
# 0         NaN    NaN             2L            NaN               NaN
# 1           -    NaN     AGAP004677            NaN               NaN
# 2           -    NaN  AGAP004677-RA     AGAP004677               NaN
# 3           -    NaN            NaN  AGAP004677-RA               NaN
# 4           -    NaN            NaN  AGAP004677-RA  AGAP004677-RB-E4
# ...       ...    ...            ...            ...               ...
# 196140      +    NaN            NaN  AGAP029375-RA               NaN
# 196141      +    NaN            NaN  AGAP029375-RA  AGAP029375-RA-E2
# 196142      +    0.0  AGAP029375-PA  AGAP029375-RA               NaN
# 196143      +    NaN            NaN  AGAP029375-RA  AGAP029375-RA-E3
# 196144      +    0.0  AGAP029375-PA  AGAP029375-RA               NaN
#
#                                               description
# 0                                                     NaN
# 1       methylenetetrahydrofolate dehydrogenase(NAD ) ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 196140                                                NaN
# 196141                                                NaN
# 196142                                                NaN
# 196143                                                NaN
# 196144                                                NaN
#
# [196145 rows x 12 columns]

# %% [markdown]
# There are 196,145 rows and 12 columns in this DataFrame. Each row provides data about an annotated feature on the *Anopheles gambiae* AgamP4 reference genome, such as a gene. The columns provide data about those features, such as the contig (chromosome arm) on which the feature occurs, and the start and end coordinates.

# %% [markdown]
# ### Example: SNP allele frequencies
#
# In [workshop 1, module 4](https://anopheles-genomic-surveillance.github.io/workshop-1/module-4-vgsc-snps.html), we encountered the [snp_allele_frequencies()](https://malariagen.github.io/vector-data/ag3/api.html#snp-allele-frequencies) function. This function returns a DataFrame of single nucleotide polymorphisms (SNPs) together with their allele frequencies in different mosquito cohorts. Let's call this function and assign the result to the variable `snp_freqs_df`.

# %%
snp_freqs_df = ag3.snp_allele_frequencies(
    transcript="AGAP004707-RD",
    cohorts="admin1_year",
    sample_sets=["AG1000G-BF-A", "AG1000G-BF-B", "AG1000G-BF-C"],
)
snp_freqs_df
# Out:
# Load SNP genotypes:   0%|          | 0/32 [00:00<?, ?it/s]
# Compute allele frequencies:   0%|          | 0/6 [00:00<?, ?it/s]
# Compute SNP effects:   0%|          | 0/9675 [00:00<?, ?it/s]
#                                                  pass_gamb_colu_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                      True
#        2358328  T          C          NaN                       True
#        2358441  A          T          NaN                       True
#        2358468  A          C          NaN                       True
#        2358581  T          A          NaN                       True
# ...                                                              ...
#        2431424  G          T          G2055V                    True
#        2431518  C          A          A2086A                    True
#        2431527  G          C          V2089V                    True
#        2431569  C          A          V2103V                    True
#        2431613  T          C          V2118A                    True
#
#                                                  pass_gamb_colu  pass_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                 True       True
#        2358328  T          C          NaN                  True       True
#        2358441  A          T          NaN                  True       True
#        2358468  A          C          NaN                  True       True
#        2358581  T          A          NaN                  True       True
# ...                                                         ...        ...
#        2431424  G          T          G2055V               True       True
#        2431518  C          A          A2086A               True       True
#        2431527  G          C          V2089V               True       True
#        2431569  C          A          V2103V               True       True
#        2431613  T          C          V2118A               True       True
#
#                                                  frq_BF-07_gamb_2004  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2358328  T          C          NaN                   0.000000
#        2358441  A          T          NaN                   0.038462
#        2358468  A          C          NaN                   0.269231
#        2358581  T          A          NaN                   0.192308
# ...                                                              ...
#        2431424  G          T          G2055V                0.000000
#        2431518  C          A          A2086A                0.038462
#        2431527  G          C          V2089V                0.038462
#        2431569  C          A          V2103V                0.038462
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.006098
#        2358328  T          C          NaN                   0.006098
#        2358441  A          T          NaN                   0.000000
#        2358468  A          C          NaN                   0.000000
#        2358581  T          A          NaN                   0.000000
# ...                                                              ...
#        2431424  G          T          G2055V                0.000000
#        2431518  C          A          A2086A                0.000000
#        2431527  G          C          V2089V                0.000000
#        2431569  C          A          V2103V                0.000000
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                       0.0
#        2358328  T          C          NaN                        0.0
#        2358441  A          T          NaN                        0.0
#        2358468  A          C          NaN                        0.0
#        2358581  T          A          NaN                        0.0
# ...                                                              ...
#        2431424  G          T          G2055V                     0.0
#        2431518  C          A          A2086A                     0.0
#        2431527  G          C          V2089V                     0.0
#        2431569  C          A          V2103V                     0.0
#        2431613  T          C          V2118A                     0.0
#
#                                                  frq_BF-09_gamb_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2358328  T          C          NaN                   0.000000
#        2358441  A          T          NaN                   0.000000
#        2358468  A          C          NaN                   0.000000
#        2358581  T          A          NaN                   0.000000
# ...                                                              ...
#        2431424  G          T          G2055V                0.005051
#        2431518  C          A          A2086A                0.000000
#        2431527  G          C          V2089V                0.000000
#        2431569  C          A          V2103V                0.000000
#        2431613  T          C          V2118A                0.005051
#
#                                                  frq_BF-09_gamb_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                       0.0
#        2358328  T          C          NaN                        0.0
#        2358441  A          T          NaN                        0.0
#        2358468  A          C          NaN                        0.0
#        2358581  T          A          NaN                        0.0
# ...                                                              ...
#        2431424  G          T          G2055V                     0.0
#        2431518  C          A          A2086A                     0.0
#        2431527  G          C          V2089V                     0.0
#        2431569  C          A          V2103V                     0.0
#        2431613  T          C          V2118A                     0.0
#
#                                                    max_af     transcript  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       0.006098  AGAP004707-RD
#        2358328  T          C          NaN        0.006098  AGAP004707-RD
#        2358441  A          T          NaN        0.038462  AGAP004707-RD
#        2358468  A          C          NaN        0.269231  AGAP004707-RD
#        2358581  T          A          NaN        0.192308  AGAP004707-RD
# ...                                                   ...            ...
#        2431424  G          T          G2055V     0.005051  AGAP004707-RD
#        2431518  C          A          A2086A     0.038462  AGAP004707-RD
#        2431527  G          C          V2089V     0.038462  AGAP004707-RD
#        2431569  C          A          V2103V     0.038462  AGAP004707-RD
#        2431613  T          C          V2118A     0.005051  AGAP004707-RD
#
#                                                                 effect  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       NON_SYNONYMOUS_CODING
#        2358328  T          C          NaN                     INTRONIC
#        2358441  A          T          NaN                     INTRONIC
#        2358468  A          C          NaN                     INTRONIC
#        2358581  T          A          NaN                     INTRONIC
# ...                                                                ...
#        2431424  G          T          G2055V     NON_SYNONYMOUS_CODING
#        2431518  C          A          A2086A         SYNONYMOUS_CODING
#        2431527  G          C          V2089V         SYNONYMOUS_CODING
#        2431569  C          A          V2103V         SYNONYMOUS_CODING
#        2431613  T          C          V2118A     NON_SYNONYMOUS_CODING
#
#                                                    impact ref_codon alt_codon  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       MODERATE       gCa       gTa
#        2358328  T          C          NaN        MODIFIER      None      None
#        2358441  A          T          NaN        MODIFIER      None      None
#        2358468  A          C          NaN        MODIFIER      None      None
#        2358581  T          A          NaN        MODIFIER      None      None
# ...                                                   ...       ...       ...
#        2431424  G          T          G2055V     MODERATE       gGc       gTc
#        2431518  C          A          A2086A          LOW       gcC       gcA
#        2431527  G          C          V2089V          LOW       gtG       gtC
#        2431569  C          A          V2103V          LOW       gtC       gtA
#        2431613  T          C          V2118A     MODERATE       gTc       gCc
#
#                                                  aa_pos ref_aa alt_aa  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V         32.0      A      V
#        2358328  T          C          NaN           NaN   None   None
#        2358441  A          T          NaN           NaN   None   None
#        2358468  A          C          NaN           NaN   None   None
#        2358581  T          A          NaN           NaN   None   None
# ...                                                 ...    ...    ...
#        2431424  G          T          G2055V     2055.0      G      V
#        2431518  C          A          A2086A     2086.0      A      A
#        2431527  G          C          V2089V     2089.0      V      V
#        2431569  C          A          V2103V     2103.0      V      V
#        2431613  T          C          V2118A     2118.0      V      A
#
#                                                                      label
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V         2L:2,358,252 C>T (A32V)
#        2358328  T          C          NaN                 2L:2,358,328 T>C
#        2358441  A          T          NaN                 2L:2,358,441 A>T
#        2358468  A          C          NaN                 2L:2,358,468 A>C
#        2358581  T          A          NaN                 2L:2,358,581 T>A
# ...                                                                    ...
#        2431424  G          T          G2055V     2L:2,431,424 G>T (G2055V)
#        2431518  C          A          A2086A     2L:2,431,518 C>A (A2086A)
#        2431527  G          C          V2089V     2L:2,431,527 G>C (V2089V)
#        2431569  C          A          V2103V     2L:2,431,569 C>A (V2103V)
#        2431613  T          C          V2118A     2L:2,431,613 T>C (V2118A)
#
# [9675 rows x 18 columns]

# %% [markdown]
# There are 9,675 rows and 18 columns in this DataFrame. Each row provides data about a SNP. The columns provide data about those SNPs, such as their effect, and the alternate allele frequency in a particular cohort of mosquitoes, e.g., the column named "frq_BF-09_colu_2012" provides the frequency in *Anopheles coluzzii* mosquitoes collected in the BF-09 (Hauts-Bassins) administrative region of Burkina Faso in 2012.

# %% [markdown]
# ### Aside: variable naming styles
#
# You may have noticed that in the examples above, whenever we assigned a DataFrame to a variable, the name of the variable either started with the prefix "`df_`" or ended with the suffix "`_df`". Here "df" stands for DataFrame, and is used just as a helpful reminder that the value of the variable is a pandas DataFrame. Using a prefix of suffix on the variable name like this is entirely optional and is up to your own coding style. You can name these variables whatever you like. Different instructors in this course prefer different styles, and you will see different styles being used in different modules.

# %% [markdown]
# ### Example: reading from a CSV file
#
# You can also create a pandas DataFrame by reading data from a file, such as a comma-separated value (CSV) file, or an Excel workbook file. Let's use the pandas [read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function to read data from a CSV file containing data from a US census that colab provides as example data for you to play with.

# %%
df_housing = pd.read_csv("sample_data/california_housing_train.csv")
df_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %% [markdown]
# This DataFrame has 17,000 rows and 9 columns. Each row provides data about a block of housing. The columns provide data about the houses within a block, such as the total number of bedrooms and the number of households.
#
# Note that you can upload your own files to Colab if you want to read in and analyse some of your own data with pandas.

# %% [markdown]
# ### Example: creating a DataFrame from scratch
#
# You can also create a DataFrame by providing the data within your code. To demonstrate this, let's create a DataFrame with data about characters in a famous science fiction book called The Hitchhiker's Guide to the Galaxy.

# %%
msbt_df = pd.DataFrame(data={
    'names': ['Okitwi', 'Neumbe', 'Ainembabazi', 'Katairo', 'Opio', 'Kirabo', 'Arinda', 'Nankoma', 'Nuwasiima', 'Katongole', 'Wanyama'],
    'age': [32, 28, 30, 33, 27, 25, 24, 26, 29, 38, 35],
    'gender': ['M', 'F', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M'],
    'Scores': [76, 70, 72, 78, 67, 65, 64, 80, 60, 61, 69]})
msbt_df
# Out:
#           names  age gender  Scores
# 0        Okitwi   32      M      76
# 1        Neumbe   28      F      70
# 2   Ainembabazi   30      M      72
# 3       Katairo   33      M      78
# 4          Opio   27      M      67
# 5        Kirabo   25      F      65
# 6        Arinda   24      F      64
# 7       Nankoma   26      F      80
# 8     Nuwasiima   29      F      60
# 9     Katongole   38      M      61
# 10      Wanyama   35      M      69

# %%
df_hitchhikers = pd.DataFrame(data={
    "name": ["Arthur Dent", "Tricia McMillan", "Ford Prefect", "Zaphod Beeblebrox", "Marvin the Paranoid Android"],
    "taxon": ["human", "human", "betelgeusian", "betelgeusian", "robot"],
    "gender": ["male", "female", "male", "male", None],
    "number_of_heads": [1, 1, 1, 2, 1],
    "intelligence": [100, 180, 120, 30, 5_000_000]
})
df_hitchhikers
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %% [markdown]
# This DataFrame has 5 rows and 5 columns. Each row provides data about a fictional character in the book. The columns provide data about each character, such as their name, taxon and number of heads (some alien species can have more than one).

# %% [markdown]
# ## Structure of a DataFrame
#
# Hopefully this will already be obvious from the examples above, but a [pandas DataFrame](https://pandas.pydata.org/docs/user_guide/dsintro.html#dataframe) is a data structure that is organised into **rows** and **columns**. Each DataFrame also has an **index**, which is a special column (or set of columns) that is shown in bold at the left of a DataFrame, and which we'll look at in more detail later.

# %%
# %%html
# <img width="90%" height="90%"src="https://storage.googleapis.com/vo_agam_release/reference/training-images/workshop-2/W2M1-1.PNG"/>
# Out:
# <img width="90%" height="90%"src="https://storage.googleapis.com/vo_agam_release/reference/training-images/workshop-2/W2M1-1.PNG"/>

# %% [markdown]
# ## Counting rows and columns
#
# If a DataFrame is large, you may find it useful to know how many rows and columns it contains. The representation of a DataFrame shows at the bottom how many rows and columns are present in the DataFrame, but you can also use the built-in `len()` function if you want to access the number of rows or columns in your code.

# %%
num_rows = len(df_hitchhikers)
num_rows
# Out:
# 5

# %%
num_cols = len(df_hitchhikers.columns)
num_cols
# Out:
# 5

# %% [markdown]
# Alternatively:

# %%
rows, columns = df_hitchhikers.shape
print('Rows =',rows)
print('Columns =',columns)
# Out:
# Rows = 5
# Columns = 5

# %%
df_hitchhikers.shape
# Out:
# (5, 5)

# %% [markdown]
# **Exercise 1 (English)**
#
# * Count the number of rows and columns in the `df_samples` DataFrame.
#
# **Exercice 1 (Français)**
#
# * Compter le nombre de lignes et de colonnes du DataFrame `df_samples`.

# %%
# Exercise 1
# Number of rows in the df_samples dataframe
num_rows = len(df_samples)
num_rows
# Out:
# 3081

# %%
# Number of columns
num_cols = len(df_samples.columns)
num_cols
# Out:
# 30

# %%
rows, columns = df_samples.shape
print('Rows =',rows)
print('Columns =',columns)
# Out:
# Rows = 3081
# Columns = 30

# %%
df_samples.shape
# Out:
# (3081, 30)

# %% [markdown]
# ## Accessing columns
#
# Often you will have a DataFrame with many columns, and you many only need to work with data from a smaller number of columns, or just a single column. Accessing one or more columns from a DataFrame can be done using the square bracket syntax after the name of a DataFrame variable. Let's see how this works.

# %% [markdown]
# ### Accessing column names
#
# First, let's access the names of all the columns in a DataFrame, to see what columns are available. You can do this by accessing the `columns` property of a DataFrame. For simplicity, let's also convert the result to a Python list, using the built-in `list()` function.

# %%
col_names = df_hitchhikers.columns
cols_list = list(col_names) # convert results into python list
cols_list
# Out:
# ['name', 'taxon', 'gender', 'number_of_heads', 'intelligence']

# %% [markdown]
# Alternatively:

# %%
col_names = list(df_hitchhikers.columns)
col_names
# Out:
# ['name', 'taxon', 'gender', 'number_of_heads', 'intelligence']

# %% [markdown]
# This can be useful especially if you have a lot of columns in a DataFrame.

# %% [markdown]
# **Exercise 2 (English)**
#
# * Access the column names of the `df_samples` DataFrame.
#
# **Exercice 2 (Français)**
#
# * Afficher les noms des colonnes du DataFrame `df_samples`.

# %% [markdown]
# Exercise 2 - Solution:

# %%
# Column names in the df_samples dataframe
column_names = list(df_samples.columns)
column_names
# Out:
# ['sample_id',
#  'partner_sample_id',
#  'contributor',
#  'country',
#  'location',
#  'year',
#  'month',
#  'latitude',
#  'longitude',
#  'sex_call',
#  'sample_set',
#  'release',
#  'quarter',
#  'aim_species_fraction_arab',
#  'aim_species_fraction_colu',
#  'aim_species_fraction_colu_no2l',
#  'aim_species_gambcolu_arabiensis',
#  'aim_species_gambiae_coluzzii',
#  'aim_species',
#  'country_iso',
#  'admin1_name',
#  'admin1_iso',
#  'admin2_name',
#  'taxon',
#  'cohort_admin1_year',
#  'cohort_admin1_month',
#  'cohort_admin1_quarter',
#  'cohort_admin2_year',
#  'cohort_admin2_month',
#  'cohort_admin2_quarter']

# %% [markdown]
# ### Accessing a single column
#
# To access a single column, give the column name as a string inside square brackets. Let's access the "name" column from the DataFrame of book characters, and assign the result to a new variable `character_name`.

# %%
character_name = df_hitchhikers["name"]
character_name
# Out:
# 0                    Arthur Dent
# 1                Tricia McMillan
# 2                   Ford Prefect
# 3              Zaphod Beeblebrox
# 4    Marvin the Paranoid Android
# Name: name, dtype: object

# %%
sample_names = df_samples['sample_id']
sample_names
# Out:
# 0       AR0047-C
# 1       AR0049-C
# 2       AR0051-C
# 3       AR0061-C
# 4       AR0078-C
#           ...
# 3076    AD0494-C
# 3077    AD0495-C
# 3078    AD0496-C
# 3079    AD0497-C
# 3080    AD0498-C
# Name: sample_id, Length: 3081, dtype: object

# %% [markdown]
# When you access a single column or row from a DataFrame, pandas returns a [Series](https://pandas.pydata.org/docs/user_guide/dsintro.html#series) object to you. Pandas uses the Series class to hold data either from a single column or a single row, i.e., a one-dimensional sequence of data values.

# %%
type(character_name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# We can also inspect the data in the column.

# %%
character_name
# Out:
# 0                    Arthur Dent
# 1                Tricia McMillan
# 2                   Ford Prefect
# 3              Zaphod Beeblebrox
# 4    Marvin the Paranoid Android
# Name: name, dtype: object

# %% [markdown]
# ### Investigating data in a column
#
# The pandas Series class has some useful functions for investigating the data in a DataFrame.
#
# E.g., let's access the "taxon" column and use the `value_counts()` functions to get a summary of the categorical data in the column.

# %%
character_taxon = df_hitchhikers["taxon"]
character_taxon.value_counts()
# Out:
# human           2
# betelgeusian    2
# robot           1
# Name: taxon, dtype: int64

# %%
# the value_counts() function for counting numerical data.
species = df_samples['taxon']
species.value_counts()
# Out:
# gambiae       1473
# coluzzii       505
# arabiensis     368
# unassigned     300
# gcx2           200
# gcx1           170
# gcx3            65
# Name: taxon, dtype: int64

# %% [markdown]
# The pandas Series class also has a `describe()` function which can be useful for investigating numerical data. Let's use it with the `number_of_heads` column.

# %%
df_hitchhikers.head
# Out:
# <bound method NDFrame.head of                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000  >

# %%
character_heads = df_hitchhikers["number_of_heads"]
character_heads.describe()
# Out:
# count    5.000000
# mean     1.200000
# std      0.447214
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      2.000000
# Name: number_of_heads, dtype: float64

# %%
# the describe() function for summarising numerical data
msbt_df_scores = msbt_df['Scores']
msbt_df_scores.describe()
# Out:
# count    11.000000
# mean     69.272727
# std       6.709559
# min      60.000000
# 25%      64.500000
# 50%      69.000000
# 75%      74.000000
# max      80.000000
# Name: Scores, dtype: float64

# %% [markdown]
# The characters in our DataFrame have at least (min) 1 and at most (max) 2 heads. The mean number of heads is 1.2, but of course this a bit silly, because number of heads is not a continuous variable.

# %% [markdown]
# **Exercise 3 (English)**
#
# * Access the "country" column from the `df_samples` DataFrame, and then use the `value_counts()` function to show the number of mosquito samples from each country.
#
# * Access the "type" column from the `df_geneset` DataFrame, and then use the `value_counts()` function to show the number of genome annotations of different types.
#
# * Access the "effect" column from the `snp_freqs_df` DataFrame, and then use the `value_counts()` function to show the number of SNPs with different effects.
#
# **Exercice 3 (Français)**
#
# * Obtenir la colonne "country" du DataFrame `df_samples` et utiliser la fonction `value_counts()` pour afficher le nombre de moustiques capturés dans chaque pays.
#
# * Obtenir la colonne "type" du DataFrame `df_geneset` et utiliser la fonction `value_counts()` pour afficher le nombre d'annotations du génome de chaque type.
#
# * Obtenir la colonne "effect" du DataFrame `snp_freqs_df` et utiliser la fonction `value_counts()` pour afficher le nombre de SNPs pour chaque effet possible.

# %%
# Number of mosquitos per country
countries = df_samples['country']
countries.value_counts()
# Out:
# Cameroon                            444
# Tanzania                            300
# Lab Cross                           297
# Burkina Faso                        296
# Uganda                              290
# Gambia, The                         279
# Mali                                225
# Guinea                              136
# Guinea-Bissau                       101
# Ghana                               100
# Kenya                                86
# Angola                               81
# Cote d'Ivoire                        80
# Democratic Republic of the Congo     76
# Mozambique                           74
# Central African Republic             73
# Gabon                                69
# Malawi                               41
# Mayotte                              23
# Equatorial Guinea                    10
# Name: country, dtype: int64

# %%
# df_geneset dataframe of gene annotations
df_geneset.head
# Out:
# <bound method NDFrame.head of             contig      source             type   start       end  score  \
# 0               2L  VectorBase       chromosome       1  49364325    NaN
# 1               2L  VectorBase             gene  157348    186936    NaN
# 2               2L  VectorBase             mRNA  157348    181305    NaN
# 3               2L  VectorBase  three_prime_UTR  157348    157495    NaN
# 4               2L  VectorBase             exon  157348    157623    NaN
# ...            ...         ...              ...     ...       ...    ...
# 196140  Y_unplaced  VectorBase   five_prime_UTR   47932     48111    NaN
# 196141  Y_unplaced  VectorBase             exon   47932     48138    NaN
# 196142  Y_unplaced  VectorBase              CDS   48112     48138    NaN
# 196143  Y_unplaced  VectorBase             exon   48301     48385    NaN
# 196144  Y_unplaced  VectorBase              CDS   48301     48385    NaN
#
#        strand  phase             ID         Parent              Name  \
# 0         NaN    NaN             2L            NaN               NaN
# 1           -    NaN     AGAP004677            NaN               NaN
# 2           -    NaN  AGAP004677-RA     AGAP004677               NaN
# 3           -    NaN            NaN  AGAP004677-RA               NaN
# 4           -    NaN            NaN  AGAP004677-RA  AGAP004677-RB-E4
# ...       ...    ...            ...            ...               ...
# 196140      +    NaN            NaN  AGAP029375-RA               NaN
# 196141      +    NaN            NaN  AGAP029375-RA  AGAP029375-RA-E2
# 196142      +    0.0  AGAP029375-PA  AGAP029375-RA               NaN
# 196143      +    NaN            NaN  AGAP029375-RA  AGAP029375-RA-E3
# 196144      +    0.0  AGAP029375-PA  AGAP029375-RA               NaN
#
#                                               description
# 0                                                     NaN
# 1       methylenetetrahydrofolate dehydrogenase(NAD ) ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 196140                                                NaN
# 196141                                                NaN
# 196142                                                NaN
# 196143                                                NaN
# 196144                                                NaN
#
# [196145 rows x 12 columns]>

# %%
# Number of gene annotation types
geneset_type = df_geneset['type']
geneset_type.value_counts()
# Out:
# exon                      72257
# CDS                       66103
# five_prime_UTR            16598
# mRNA                      14979
# gene                      13057
# three_prime_UTR           11665
# ncRNA_gene                  729
# tRNA                        362
# rRNA                        242
# pre_miRNA                    77
# snRNA                        35
# pseudogene                   10
# pseudogenic_transcript       10
# chromosome                    8
# ncRNA                         4
# SRP_RNA                       3
# snoRNA                        2
# lnc_RNA                       2
# RNase_MRP_RNA                 1
# RNase_P_RNA                   1
# Name: type, dtype: int64

# %%
# Contig type counts
contig_counts = df_geneset['contig'].value_counts()
contig_counts
# Out:
# 2R            56294
# 2L            45650
# 3R            41330
# 3L            30624
# X             17498
# UNKN           4604
# Mt              125
# Y_unplaced       20
# Name: contig, dtype: int64

# %%
# SNP effects count
snp_effect = snp_freqs_df['effect']
snp_effect.value_counts()
# Out:
# INTRONIC                 9467
# NON_SYNONYMOUS_CODING     121
# SYNONYMOUS_CODING          56
# STOP_GAINED                14
# SPLICE_REGION               9
# SPLICE_CORE                 8
# Name: effect, dtype: int64

# %% [markdown]
# ### Accessing multiple columns
#
# To access multiple columns, provide the column names as a list of strings. Let's access the "name", "taxon" and "number_of_heads" columns from the DataFrame of book characters, and assign the resulting DataFrame to a new variable `df_hh`.

# %%
selected_cols = ["name", "taxon", "number_of_heads"]
df_hh = df_hitchhikers[selected_cols]
df_hh
# Out:
#                           name         taxon  number_of_heads
# 0                  Arthur Dent         human                1
# 1              Tricia McMillan         human                1
# 2                 Ford Prefect  betelgeusian                1
# 3            Zaphod Beeblebrox  betelgeusian                2
# 4  Marvin the Paranoid Android         robot                1

# %% [markdown]
# You can also put the list of columns directly inside the square brackets, which would give the same result.

# %%
df_hh = df_hitchhikers[["name", "taxon", "number_of_heads"]]
df_hh
# Out:
#                           name         taxon  number_of_heads
# 0                  Arthur Dent         human                1
# 1              Tricia McMillan         human                1
# 2                 Ford Prefect  betelgeusian                1
# 3            Zaphod Beeblebrox  betelgeusian                2
# 4  Marvin the Paranoid Android         robot                1

# %% [markdown]
# **Exercise 4 (English)**
#
# * Create a new DataFrame containing only the "sample_id", "country" and "year" columns from the `df_samples` DataFrame.
# * Create a new DataFrame containing only the "ID", "contig", "start" and "end" columns from the `df_geneset` DataFrame.
# * Create a new DataFrame containing only the frequency columns from the `snp_freqs_df` DataFrame (hint: the names of these columns all begin with "frq_").
#
# **Exercice 4 (Français)**
#
# * Créer un nouveau DataFrame contenant seulement les colonnes "sample_id", "country" et "year" du DataFrame `df_samples`.
#
# * Créer un nouveau DataFrame contenant seulement les colonnes "ID", "contig", "start" et "end" du DataFrame `df_geneset`.
#
# * Créer un nouveau DataFrame contenant seulement les colonnes contenant les fréquences du DataFrame `snp_freqs_df` (Indice: les noms de ces colonnes commencent tous par "frq_").

# %%
# select columns from df_samples dataframe
sample_cols_df = df_samples[['sample_id', 'country', 'year']]
sample_cols_df
# Out:
#      sample_id    country  year
# 0     AR0047-C     Angola  2009
# 1     AR0049-C     Angola  2009
# 2     AR0051-C     Angola  2009
# 3     AR0061-C     Angola  2009
# 4     AR0078-C     Angola  2009
# ...        ...        ...   ...
# 3076  AD0494-C  Lab Cross    -1
# 3077  AD0495-C  Lab Cross    -1
# 3078  AD0496-C  Lab Cross    -1
# 3079  AD0497-C  Lab Cross    -1
# 3080  AD0498-C  Lab Cross    -1
#
# [3081 rows x 3 columns]

# %%
# select columns from df_geneset dataframe
geneset_cols_df = df_geneset[["ID", "contig", "start", "end"]]
geneset_cols_df
# Out:
#                    ID      contig   start       end
# 0                  2L          2L       1  49364325
# 1          AGAP004677          2L  157348    186936
# 2       AGAP004677-RA          2L  157348    181305
# 3                 NaN          2L  157348    157495
# 4                 NaN          2L  157348    157623
# ...               ...         ...     ...       ...
# 196140            NaN  Y_unplaced   47932     48111
# 196141            NaN  Y_unplaced   47932     48138
# 196142  AGAP029375-PA  Y_unplaced   48112     48138
# 196143            NaN  Y_unplaced   48301     48385
# 196144  AGAP029375-PA  Y_unplaced   48301     48385
#
# [196145 rows x 4 columns]

# %%
# frequency columns from snp_freqs_df dataframe
freq_cols = snp_freqs_df.filter(regex=r'^frq_').columns
freq_cols
freq_df = snp_freqs_df[freq_cols]
freq_df
# Out:
#                                                  frq_BF-07_gamb_2004  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2358328  T          C          NaN                   0.000000
#        2358441  A          T          NaN                   0.038462
#        2358468  A          C          NaN                   0.269231
#        2358581  T          A          NaN                   0.192308
# ...                                                              ...
#        2431424  G          T          G2055V                0.000000
#        2431518  C          A          A2086A                0.038462
#        2431527  G          C          V2089V                0.038462
#        2431569  C          A          V2103V                0.038462
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.006098
#        2358328  T          C          NaN                   0.006098
#        2358441  A          T          NaN                   0.000000
#        2358468  A          C          NaN                   0.000000
#        2358581  T          A          NaN                   0.000000
# ...                                                              ...
#        2431424  G          T          G2055V                0.000000
#        2431518  C          A          A2086A                0.000000
#        2431527  G          C          V2089V                0.000000
#        2431569  C          A          V2103V                0.000000
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                       0.0
#        2358328  T          C          NaN                        0.0
#        2358441  A          T          NaN                        0.0
#        2358468  A          C          NaN                        0.0
#        2358581  T          A          NaN                        0.0
# ...                                                              ...
#        2431424  G          T          G2055V                     0.0
#        2431518  C          A          A2086A                     0.0
#        2431527  G          C          V2089V                     0.0
#        2431569  C          A          V2103V                     0.0
#        2431613  T          C          V2118A                     0.0
#
#                                                  frq_BF-09_gamb_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2358328  T          C          NaN                   0.000000
#        2358441  A          T          NaN                   0.000000
#        2358468  A          C          NaN                   0.000000
#        2358581  T          A          NaN                   0.000000
# ...                                                              ...
#        2431424  G          T          G2055V                0.005051
#        2431518  C          A          A2086A                0.000000
#        2431527  G          C          V2089V                0.000000
#        2431569  C          A          V2103V                0.000000
#        2431613  T          C          V2118A                0.005051
#
#                                                  frq_BF-09_gamb_2014
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                       0.0
#        2358328  T          C          NaN                        0.0
#        2358441  A          T          NaN                        0.0
#        2358468  A          C          NaN                        0.0
#        2358581  T          A          NaN                        0.0
# ...                                                              ...
#        2431424  G          T          G2055V                     0.0
#        2431518  C          A          A2086A                     0.0
#        2431527  G          C          V2089V                     0.0
#        2431569  C          A          V2103V                     0.0
#        2431613  T          C          V2118A                     0.0
#
# [9675 rows x 5 columns]

# %% [markdown]
# ## Accessing rows
#
# Now we've seen how to access columns, let's see how to access rows. To access rows by their position within a DataFrame, we can use the `iloc` property.

# %% [markdown]
# ### Accessing a single row
#
# To access a single row, we use the `iloc` property, then provide the row number as an integer inside square brackets, remembering that numbering starts from 0 in Python. For example, access the first row of our DataFrame of book characters, and assign the result to a variable `first_row`.

# %%
first_row = df_hitchhikers.iloc[0] # iloc = integer location

# %% [markdown]
# When accessing a single row, pandas returns a Series.

# %%
type(first_row)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Inspect the data in the row.

# %%
first_row
# Out:
# name               Arthur Dent
# taxon                    human
# gender                    male
# number_of_heads              1
# intelligence               100
# Name: 0, dtype: object

# %% [markdown]
# Access specific data values within the row.

# %%
first_row["name"]
# Out:
# 'Arthur Dent'

# %% [markdown]
# Alternatively, to access a particular column value in the first row:
# - select the column using integer-based indexing `.iloc[0]`, then select the desired value using the column name e.g `['name']`

# %%
first = df_hitchhikers.iloc[0]['name']
first
# Out:
# 'Arthur Dent'

# %%
first_row["number_of_heads"]
# Out:
# 1

# %% [markdown]
# **Exercise 5 (English)**
#
# * Access the 81st row in the `df_samples` DataFrame. What country did this mosquito sample come from? (Remember: numbering starts from 0 in Python.)
#
# * Access the 73,287th row in the `df_geneset` DataFrame. What type of annotation is this? What is its Name?
#
# **Exercice 5 (Français)**
#
# * Obtenir la 81ème ligne du DataFrame `df_samples`. De quel pays est issu ce moustique? (Indice: les indices commencent à 0 en Python)
#
# * Obtenir la 73 287ème ligne du DataFrame `df_geneset`. De quel type d'annotation s'agit-il? Quel est son nom?

# %%
row81 = df_samples.iloc[80]['country']
row81    # Angola
# Out:
# 'Angola'

# %%
# eighty first row of df_samples
row_81 = df_samples.iloc[80]
print(row_81)

# sample from Angola
row_81['country'] # Angola
# Out:
# sample_id                                            AR0053-C
# partner_sample_id                                      LUA053
# contributor                                        Joao Pinto
# country                                                Angola
# location                                               Luanda
# year                                                     2009
# month                                                       4
# latitude                                               -8.884
# longitude                                              13.302
# sex_call                                                    F
# sample_set                                         AG1000G-AO
# release                                                   3.0
# quarter                                                     2
# aim_species_fraction_arab                            0.000384
# aim_species_fraction_colu                            0.915767
# aim_species_fraction_colu_no2l                       0.945228
# aim_species_gambcolu_arabiensis                      gambcolu
# aim_species_gambiae_coluzzii                         coluzzii
# aim_species                                          coluzzii
# country_iso                                               AGO
# admin1_name                                            Luanda
# admin1_iso                                             AO-LUA
# admin2_name                                            Luanda
# taxon                                                coluzzii
# cohort_admin1_year                           AO-LUA_colu_2009
# cohort_admin1_month                       AO-LUA_colu_2009_04
# cohort_admin1_quarter                     AO-LUA_colu_2009_Q2
# cohort_admin2_year                    AO-LUA_Luanda_colu_2009
# cohort_admin2_month                AO-LUA_Luanda_colu_2009_04
# cohort_admin2_quarter              AO-LUA_Luanda_colu_2009_Q2
# Name: 80, dtype: object
# 'Angola'

# %%
row73287 = df_geneset.iloc[73_286][['type', 'Name']]
row73287  # gene  # CYP6AA1
# Out:
# type       gene
# Name    CYP6AA1
# Name: 73286, dtype: object

# %%
# 73,287th row in the df_geneset DataFrame
row_73287 = df_geneset.iloc[73286]
print(row_73287)

# type of annotation
row_73287['type'] # gene
# its name
row_73287['Name'] # CYP6AA1
# Out:
# contig                                                       2R
# source                                               VectorBase
# type                                                       gene
# start                                                  28480576
# end                                                    28482637
# score                                                       NaN
# strand                                                        -
# phase                                                       NaN
# ID                                                   AGAP002862
# Parent                                                      NaN
# Name                                                    CYP6AA1
# description    cytochrome P450 [Source:VB Community Annotation]
# Name: 73286, dtype: object
# 'CYP6AA1'

# %% [markdown]
# ### Accessing multiple rows
#
# We can also use `iloc` to access multiple rows,from some start position to some end position. To do this we provide two integers separated by a colon (":") which is called a slice.
#
# As well as remembering that numbering starts from zero, we also have to remember that slices include the start position but do not include the stop position. E.g., to access the first two rows, provide the start and stop positions 0 and 2. This returns a new DataFrame with just the selected rows within the slice.

# %%
first_two_rows = df_hitchhikers.iloc[0:2]
first_two_rows
# Out:
#               name  taxon  gender  number_of_heads  intelligence
# 0      Arthur Dent  human    male                1           100
# 1  Tricia McMillan  human  female                1           180

# %% [markdown]
# **Exercise 6 (English)**
#
# * Access rows starting from the 6th row up to and including the 10th row in the `df_samples` DataFrame.
#
# **Exercice 6 (Français)**
#
# * Obtenir toutes les lignes entre la 6ème et la 10ème (incluses) du DataFrame `df_samples`.

# %%
# 6th to 10th row including 10th in df_samples dataframe
rows_six_ten = df_samples.iloc[5:10]
rows_six_ten
# Out:
#   sample_id partner_sample_id contributor country location  year  month  \
# 5  AR0080-C            LUA080  Joao Pinto  Angola   Luanda  2009      4
# 6  AR0084-C            LUA084  Joao Pinto  Angola   Luanda  2009      4
# 7  AR0097-C            LUA097  Joao Pinto  Angola   Luanda  2009      4
# 8  AR0072-C            LUA072  Joao Pinto  Angola   Luanda  2009      4
# 9  AR0094-C            LUA094  Joao Pinto  Angola   Luanda  2009      4
#
#    latitude  longitude sex_call  ... admin1_name admin1_iso  admin2_name  \
# 5    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 6    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 7    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 8    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 9    -8.884     13.302        M  ...      Luanda     AO-LUA       Luanda
#
#       taxon  cohort_admin1_year  cohort_admin1_month cohort_admin1_quarter  \
# 5  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 6  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 7  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 8  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 9  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
#
#         cohort_admin2_year         cohort_admin2_month  \
# 5  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 6  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 7  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 8  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 9  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
#
#         cohort_admin2_quarter
# 5  AO-LUA_Luanda_colu_2009_Q2
# 6  AO-LUA_Luanda_colu_2009_Q2
# 7  AO-LUA_Luanda_colu_2009_Q2
# 8  AO-LUA_Luanda_colu_2009_Q2
# 9  AO-LUA_Luanda_colu_2009_Q2
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Indexes
#
# Every pandas DataFrame has an index, which is a special column (or set of columns) which can be used to access rows quickly and conveniently. In particular, indexes can be used to assign a label to every row, and then use that label to locate and access matching rows.
#
# For example, when working with our DataFrame of book characters, we might want to access rows using the name of the character. To do this, we can set the "name" column as the index.

# %%
df_hitchhikers
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %% [markdown]
# To Set one column as index:

# %%
df_hitchhikers_index1 = df_hitchhikers.set_index('name')
df_hitchhikers_index1
# Out:
#                                     taxon  gender  number_of_heads  \
# name
# Arthur Dent                         human    male                1
# Tricia McMillan                     human  female                1
# Ford Prefect                 betelgeusian    male                1
# Zaphod Beeblebrox            betelgeusian    male                2
# Marvin the Paranoid Android         robot    None                1
#
#                              intelligence
# name
# Arthur Dent                           100
# Tricia McMillan                       180
# Ford Prefect                          120
# Zaphod Beeblebrox                      30
# Marvin the Paranoid Android       5000000

# %% [markdown]
# To set 3 columns as index:

# %%
df_hitchhikers_index2 = df_hitchhikers.set_index(['name', 'taxon', 'gender'])
df_hitchhikers_index2
# Out:
#                                                  number_of_heads  intelligence
# name                        taxon        gender
# Arthur Dent                 human        male                  1           100
# Tricia McMillan             human        female                1           180
# Ford Prefect                betelgeusian male                  1           120
# Zaphod Beeblebrox           betelgeusian male                  2            30
# Marvin the Paranoid Android robot        NaN                   1       5000000

# %%
df_hitchhikers.reset_index(drop=True)
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %%
df_hitchhikers_indexed = df_hitchhikers.set_index('name')
df_hitchhikers_indexed
# Out:
#                                     taxon  gender  number_of_heads  \
# name
# Arthur Dent                         human    male                1
# Tricia McMillan                     human  female                1
# Ford Prefect                 betelgeusian    male                1
# Zaphod Beeblebrox            betelgeusian    male                2
# Marvin the Paranoid Android         robot    None                1
#
#                              intelligence
# name
# Arthur Dent                           100
# Tricia McMillan                       180
# Ford Prefect                          120
# Zaphod Beeblebrox                      30
# Marvin the Paranoid Android       5000000

# %% [markdown]
# The DataFrame `df_hitchhikers_indexed` has the same data as before, but notice that the "name" column has moved to the left and is shown in bold. This shows us that the "name" column is now being used as the DataFrame index.
#
# Now that we've set a useful index, we can use the `loc` property to locate rows with a particular name. E.g., locate the row where the character's name is "Tricia McMillan".

# %%
trillian = df_hitchhikers_indexed.loc["Tricia McMillan"]

# %% [markdown]
# This indexing action locates a single row, and so pandas returns a Series.

# %%
type(trillian)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Inspect the row of data we located.

# %%
trillian
# Out:
# taxon               human
# gender             female
# number_of_heads         1
# intelligence          180
# Name: Tricia McMillan, dtype: object

# %% [markdown]
# It's also useful to know that you can always reset the index back to the default, using the `reset_index()` function. The default is to index the DataFrame with integers.

# %%
df_hitchhikers_reset = df_hitchhikers_indexed.reset_index()
df_hitchhikers_reset
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %% [markdown]
# **Exercise 7 (English)**
#
# * Set the "sample_id" column as the index on the `df_samples` DataFrame, then locate the row with sample identifier "BK0055-C". Where was this mosquito collected?
# * Set the "ID" column as the index on the `df_geneset` DataFrame, then locate the row with identifier "AGAP000818". What is the name of this gene?
#
# **Exercice 7 (Français)**
#
# * Faire de la colonne "sample_id" l'index du DataFrame `df_samples` et ensuite trouver la ligne avec comme identificant d'échantillon "BK0055-C". D'où est issu ce moustique?
#
# * Faire de la colonne "ID" l'index du DataFrame `df_geneset` et ensuite trouver la ligne avec comme identifiant "AGAP000818". Quel est le nom de ce gène?

# %% [markdown]
# ### Exercise 7, Part 1:**bold text**

# %%
df_samples.head()
# Out:
#   sample_id partner_sample_id contributor country location  year  month  \
# 0  AR0047-C            LUA047  Joao Pinto  Angola   Luanda  2009      4
# 1  AR0049-C            LUA049  Joao Pinto  Angola   Luanda  2009      4
# 2  AR0051-C            LUA051  Joao Pinto  Angola   Luanda  2009      4
# 3  AR0061-C            LUA061  Joao Pinto  Angola   Luanda  2009      4
# 4  AR0078-C            LUA078  Joao Pinto  Angola   Luanda  2009      4
#
#    latitude  longitude sex_call  ... admin1_name admin1_iso  admin2_name  \
# 0    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 1    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 2    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 3    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
# 4    -8.884     13.302        F  ...      Luanda     AO-LUA       Luanda
#
#       taxon  cohort_admin1_year  cohort_admin1_month cohort_admin1_quarter  \
# 0  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 1  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 2  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 3  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
# 4  coluzzii    AO-LUA_colu_2009  AO-LUA_colu_2009_04   AO-LUA_colu_2009_Q2
#
#         cohort_admin2_year         cohort_admin2_month  \
# 0  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 1  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 2  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 3  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
# 4  AO-LUA_Luanda_colu_2009  AO-LUA_Luanda_colu_2009_04
#
#         cohort_admin2_quarter
# 0  AO-LUA_Luanda_colu_2009_Q2
# 1  AO-LUA_Luanda_colu_2009_Q2
# 2  AO-LUA_Luanda_colu_2009_Q2
# 3  AO-LUA_Luanda_colu_2009_Q2
# 4  AO-LUA_Luanda_colu_2009_Q2
#
# [5 rows x 30 columns]

# %%
# setting sample_id as index of the df_samples
df_samples_indexed = df_samples.set_index('sample_id')
df_samples_indexed

# row with BK0055-C
BK0055_C = df_samples_indexed.loc['BK0055-C']

# where mosquito was picked
BK0055_C[['location', 'country']] # Bangui, Central Africa Republic
# Out:
# location                      Bangui
# country     Central African Republic
# Name: BK0055-C, dtype: object

# %% [markdown]
# Alternatively:

# %%
df_samples.set_index('sample_id').loc['BK0055-C'][['country', 'location', 'admin2_name']]
# Out:
# country        Central African Republic
# location                         Bangui
# admin2_name                      Bangui
# Name: BK0055-C, dtype: object

# %% [markdown]
# ### Exercise 7, Part 2:

# %%
df_geneset.head()
# Out:
#   contig      source             type   start       end  score strand  phase  \
# 0     2L  VectorBase       chromosome       1  49364325    NaN    NaN    NaN
# 1     2L  VectorBase             gene  157348    186936    NaN      -    NaN
# 2     2L  VectorBase             mRNA  157348    181305    NaN      -    NaN
# 3     2L  VectorBase  three_prime_UTR  157348    157495    NaN      -    NaN
# 4     2L  VectorBase             exon  157348    157623    NaN      -    NaN
#
#               ID         Parent              Name  \
# 0             2L            NaN               NaN
# 1     AGAP004677            NaN               NaN
# 2  AGAP004677-RA     AGAP004677               NaN
# 3            NaN  AGAP004677-RA               NaN
# 4            NaN  AGAP004677-RA  AGAP004677-RB-E4
#
#                                          description
# 0                                                NaN
# 1  methylenetetrahydrofolate dehydrogenase(NAD ) ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# ID column as index of geneset_df
geneset_df_indexed = df_geneset.set_index('ID')
geneset_df_indexed

# row with "AGAP000818"
AGAP000818_row = geneset_df_indexed.loc["AGAP000818"]

# gene name
AGAP000818_row['Name'] # CYP9K1
# Out:
# 'CYP9K1'

# %% [markdown]
# Alternatively:

# %%
df_geneset.set_index('ID').loc['AGAP000818'][['type', 'Name']]
# Out:
# type      gene
# Name    CYP9K1
# Name: AGAP000818, dtype: object

# %% [markdown]
# ## Queries
#
# DataFrames also provide a `query()` function, which can be used to select rows matching some condition or combination of conditions. The `query()` function accepts a string containing a query expression.
#
# Let's query the book characters DataFrame to select only rows where the value of the "taxon" column is "human". To match a value we use the "==" operator.

# %%
df_hitchhikers.head()
# Out:
#                           name         taxon  gender  number_of_heads  \
# 0                  Arthur Dent         human    male                1
# 1              Tricia McMillan         human  female                1
# 2                 Ford Prefect  betelgeusian    male                1
# 3            Zaphod Beeblebrox  betelgeusian    male                2
# 4  Marvin the Paranoid Android         robot    None                1
#
#    intelligence
# 0           100
# 1           180
# 2           120
# 3            30
# 4       5000000

# %%
df_human_hitchhikers = df_hitchhikers.query("taxon == ['human', 'robot']")
df_human_hitchhikers
# Out:
#                           name  taxon  gender  number_of_heads  intelligence
# 0                  Arthur Dent  human    male                1           100
# 1              Tricia McMillan  human  female                1           180
# 4  Marvin the Paranoid Android  robot    None                1       5000000

# %% [markdown]
# Let's do the opposite, selecting only rows where the value of the "taxon" column is not "human", using the "!=" operator.

# %%
df_non_human_hitchhikers = df_hitchhikers.query("taxon != 'human'")
df_non_human_hitchhikers
# Out:
#                           name         taxon gender  number_of_heads  \
# 2                 Ford Prefect  betelgeusian   male                1
# 3            Zaphod Beeblebrox  betelgeusian   male                2
# 4  Marvin the Paranoid Android         robot   None                1
#
#    intelligence
# 2           120
# 3            30
# 4       5000000

# %%
df_non_human_hitchhikers = df_hitchhikers.query("taxon == ['robot', 'betelgeusian']")
df_non_human_hitchhikers
# Out:
#                           name         taxon gender  number_of_heads  \
# 2                 Ford Prefect  betelgeusian   male                1
# 3            Zaphod Beeblebrox  betelgeusian   male                2
# 4  Marvin the Paranoid Android         robot   None                1
#
#    intelligence
# 2           120
# 3            30
# 4       5000000

# %% [markdown]
# Let's query a numerical field using the ">" greater than operator.

# %%
df_multi_headed_hitchhikers = df_hitchhikers.query("number_of_heads > 1")
df_multi_headed_hitchhikers
# Out:
#                 name         taxon gender  number_of_heads  intelligence
# 3  Zaphod Beeblebrox  betelgeusian   male                2            30

# %% [markdown]
# A query expression can combine conditions on multiple columns using "and" and "or". E.g., find rows where the value of the "taxon" column is "human" and the value of the "number_of_heads" column is 1.

# %%
df_non_human_one_headed_hitchhikers = df_hitchhikers.query(
    "taxon != 'human' and number_of_heads == 1"
)
df_non_human_one_headed_hitchhikers
# Out:
#                           name         taxon gender  number_of_heads  \
# 2                 Ford Prefect  betelgeusian   male                1
# 4  Marvin the Paranoid Android         robot   None                1
#
#    intelligence
# 2           120
# 4       5000000

# %%
# Male and human
df_hitchhikers.query("taxon == 'human' and gender ==  'male'")
# Out:
#           name  taxon gender  number_of_heads  intelligence
# 0  Arthur Dent  human   male                1           100

# %% [markdown]
# ## **Exercise 8 (English)**
#
# * Query the `df_samples` DataFrame to select mosquitoes collected in Burkina Faso.
# * Query the `df_samples` DataFrame to select mosquitoes collected in Burkina Faso in 2014.
# * Query the `df_samples` DataFrame to select Anopheles coluzzii mosquitoes collected in Burkina Faso in 2014 (hint: `taxon == 'coluzzii'`).
# * Query the `snp_freqs_df` DataFrame to select SNPs which change the protein sequence (hint: `effect == 'NON_SYNONYMOUS_CODING'`).
# * Query the `snp_freqs_df` DataFrame to select SNPs which change the protein sequence and which occur above 5% frequency in at least one cohort (hint: `max_af > 0.05`).

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# ### Part 1 - Burkina Faso mosquitoes

# %%
# Mosquitoes collected from Burkina Faso
Burkina_mos_df = df_samples.query("country == 'Burkina Faso'")
Burkina_mos_df
# Out:
#      sample_id partner_sample_id    contributor       country      location  \
# 81   AB0085-Cx             BF2-4    Austin Burt  Burkina Faso          Pala
# 82   AB0086-Cx             BF2-6    Austin Burt  Burkina Faso          Pala
# 83    AB0087-C             BF3-3    Austin Burt  Burkina Faso  Bana Village
# 84    AB0088-C             BF3-5    Austin Burt  Burkina Faso  Bana Village
# 85   AB0089-Cx             BF3-8    Austin Burt  Burkina Faso  Bana Village
# ..         ...               ...            ...           ...           ...
# 372   AB0314-C              6775  Nora Besansky  Burkina Faso    Monomtenga
# 373   AB0315-C              6777  Nora Besansky  Burkina Faso    Monomtenga
# 374   AB0316-C              6779  Nora Besansky  Burkina Faso    Monomtenga
# 375   AB0318-C              5072  Nora Besansky  Burkina Faso    Monomtenga
# 376   AB0325-C              1403  Nora Besansky  Burkina Faso    Monomtenga
#
#      year  month  latitude  longitude sex_call  ...    admin1_name admin1_iso  \
# 81   2012      7    11.151     -4.235        F  ...  Hauts-Bassins      BF-09
# 82   2012      7    11.151     -4.235        F  ...  Hauts-Bassins      BF-09
# 83   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 84   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 85   2012      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# ..    ...    ...       ...        ...      ...  ...            ...        ...
# 372  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 373  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 374  2004      8    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 375  2004      7    12.060     -1.170        F  ...     Centre-Sud      BF-07
# 376  2004      6    12.060     -1.170        F  ...     Centre-Sud      BF-07
#
#      admin2_name     taxon  cohort_admin1_year  cohort_admin1_month  \
# 81         Houet   gambiae     BF-09_gamb_2012   BF-09_gamb_2012_07
# 82         Houet   gambiae     BF-09_gamb_2012   BF-09_gamb_2012_07
# 83         Houet  coluzzii     BF-09_colu_2012   BF-09_colu_2012_07
# 84         Houet  coluzzii     BF-09_colu_2012   BF-09_colu_2012_07
# 85         Houet  coluzzii     BF-09_colu_2012   BF-09_colu_2012_07
# ..           ...       ...                 ...                  ...
# 372       Bazega   gambiae     BF-07_gamb_2004   BF-07_gamb_2004_08
# 373       Bazega   gambiae     BF-07_gamb_2004   BF-07_gamb_2004_08
# 374       Bazega   gambiae     BF-07_gamb_2004   BF-07_gamb_2004_08
# 375       Bazega   gambiae     BF-07_gamb_2004   BF-07_gamb_2004_07
# 376       Bazega   gambiae     BF-07_gamb_2004   BF-07_gamb_2004_06
#
#     cohort_admin1_quarter      cohort_admin2_year        cohort_admin2_month  \
# 81     BF-09_gamb_2012_Q3   BF-09_Houet_gamb_2012   BF-09_Houet_gamb_2012_07
# 82     BF-09_gamb_2012_Q3   BF-09_Houet_gamb_2012   BF-09_Houet_gamb_2012_07
# 83     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# 84     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# 85     BF-09_colu_2012_Q3   BF-09_Houet_colu_2012   BF-09_Houet_colu_2012_07
# ..                    ...                     ...                        ...
# 372    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 373    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 374    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_08
# 375    BF-07_gamb_2004_Q3  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_07
# 376    BF-07_gamb_2004_Q2  BF-07_Bazega_gamb_2004  BF-07_Bazega_gamb_2004_06
#
#          cohort_admin2_quarter
# 81    BF-09_Houet_gamb_2012_Q3
# 82    BF-09_Houet_gamb_2012_Q3
# 83    BF-09_Houet_colu_2012_Q3
# 84    BF-09_Houet_colu_2012_Q3
# 85    BF-09_Houet_colu_2012_Q3
# ..                         ...
# 372  BF-07_Bazega_gamb_2004_Q3
# 373  BF-07_Bazega_gamb_2004_Q3
# 374  BF-07_Bazega_gamb_2004_Q3
# 375  BF-07_Bazega_gamb_2004_Q3
# 376  BF-07_Bazega_gamb_2004_Q2
#
# [296 rows x 30 columns]

# %% [markdown]
# ### Part 2 - Burkina Faso mosquitoes collected in 2014

# %%
# Mosquitoes collected from Burkina Faso in 2014
Burkina_mos14_df = df_samples.query("country == 'Burkina Faso' and year == 2014")
Burkina_mos14_df.head()
# Out:
#     sample_id partner_sample_id  contributor       country      location  \
# 262  AB0326-C            BF18-1  Austin Burt  Burkina Faso  Bana Village
# 263  AB0327-C            BF18-3  Austin Burt  Burkina Faso  Bana Village
# 264  AB0328-C            BF18-4  Austin Burt  Burkina Faso  Bana Village
# 265  AB0329-C            BF18-5  Austin Burt  Burkina Faso  Bana Village
# 266  AB0330-C            BF18-6  Austin Burt  Burkina Faso  Bana Village
#
#      year  month  latitude  longitude sex_call  ...    admin1_name admin1_iso  \
# 262  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 263  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 264  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 265  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 266  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
#
#      admin2_name     taxon  cohort_admin1_year  cohort_admin1_month  \
# 262        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 263        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 264        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 265        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 266        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
#
#     cohort_admin1_quarter     cohort_admin2_year       cohort_admin2_month  \
# 262    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 263    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 264    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 265    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 266    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
#
#         cohort_admin2_quarter
# 262  BF-09_Houet_colu_2014_Q3
# 263  BF-09_Houet_colu_2014_Q3
# 264  BF-09_Houet_colu_2014_Q3
# 265  BF-09_Houet_colu_2014_Q3
# 266  BF-09_Houet_colu_2014_Q3
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Part 3 - Burkina Faso An. coluzzii mosquitoes collected in 2014

# %%
# A. coluzzii mosquitoes collected from Burkina Faso in 2014
Burkina_coluzzii_df = df_samples.query("country == 'Burkina Faso'and year ==2014 and taxon =='coluzzii'")
Burkina_coluzzii_df
# Out:
#     sample_id partner_sample_id  contributor       country        location  \
# 262  AB0326-C            BF18-1  Austin Burt  Burkina Faso    Bana Village
# 263  AB0327-C            BF18-3  Austin Burt  Burkina Faso    Bana Village
# 264  AB0328-C            BF18-4  Austin Burt  Burkina Faso    Bana Village
# 265  AB0329-C            BF18-5  Austin Burt  Burkina Faso    Bana Village
# 266  AB0330-C            BF18-6  Austin Burt  Burkina Faso    Bana Village
# 267  AB0331-C            BF18-9  Austin Burt  Burkina Faso    Bana Village
# 268  AB0332-C           BF18-10  Austin Burt  Burkina Faso    Bana Village
# 270  AB0334-C           BF18-12  Austin Burt  Burkina Faso    Bana Village
# 271  AB0337-C           BF22-15  Austin Burt  Burkina Faso    Bana Village
# 272  AB0338-C           BF18-13  Austin Burt  Burkina Faso    Bana Village
# 273  AB0339-C           BF18-14  Austin Burt  Burkina Faso    Bana Village
# 274  AB0340-C           BF18-15  Austin Burt  Burkina Faso    Bana Village
# 275  AB0341-C           BF18-16  Austin Burt  Burkina Faso    Bana Village
# 276  AB0348-C           BF22-50  Austin Burt  Burkina Faso    Bana Village
# 277  AB0351-C            BF23-6  Austin Burt  Burkina Faso    Bana Village
# 278  AB0352-C           BF18-46  Austin Burt  Burkina Faso    Bana Village
# 279  AB0354-C           BF18-21  Austin Burt  Burkina Faso    Bana Village
# 280  AB0355-C           BF18-22  Austin Burt  Burkina Faso    Bana Village
# 281  AB0356-C           BF18-23  Austin Burt  Burkina Faso    Bana Village
# 282  AB0357-C           BF18-24  Austin Burt  Burkina Faso    Bana Village
# 283  AB0358-C           BF18-25  Austin Burt  Burkina Faso    Bana Village
# 284  AB0359-C           BF18-26  Austin Burt  Burkina Faso    Bana Village
# 285  AB0360-C           BF18-28  Austin Burt  Burkina Faso    Bana Village
# 286  AB0361-C           BF18-29  Austin Burt  Burkina Faso    Bana Village
# 287  AB0362-C           BF18-31  Austin Burt  Burkina Faso    Bana Village
# 288  AB0363-C           BF18-32  Austin Burt  Burkina Faso    Bana Village
# 289  AB0364-C           BF18-33  Austin Burt  Burkina Faso    Bana Village
# 290  AB0365-C           BF18-34  Austin Burt  Burkina Faso    Bana Village
# 291  AB0366-C           BF18-35  Austin Burt  Burkina Faso    Bana Village
# 292  AB0367-C           BF18-36  Austin Burt  Burkina Faso    Bana Village
# 293  AB0368-C           BF18-37  Austin Burt  Burkina Faso    Bana Village
# 294  AB0369-C           BF18-38  Austin Burt  Burkina Faso    Bana Village
# 295  AB0370-C           BF18-42  Austin Burt  Burkina Faso    Bana Village
# 296  AB0371-C           BF18-44  Austin Burt  Burkina Faso    Bana Village
# 297  AB0372-C           BF18-45  Austin Burt  Burkina Faso    Bana Village
# 307  AB0396-C            BF14-8  Austin Burt  Burkina Faso    Bana Village
# 308  AB0397-C            BF14-9  Austin Burt  Burkina Faso    Bana Village
# 309  AB0398-C           BF14-10  Austin Burt  Burkina Faso    Bana Village
# 310  AB0399-C           BF14-11  Austin Burt  Burkina Faso    Bana Village
# 311  AB0400-C           BF14-12  Austin Burt  Burkina Faso    Bana Village
# 312  AB0403-C           BF14-16  Austin Burt  Burkina Faso    Bana Village
# 313  AB0404-C           BF14-18  Austin Burt  Burkina Faso    Bana Village
# 314  AB0409-C           BF14-21  Austin Burt  Burkina Faso    Bana Village
# 315  AB0410-C           BF20-54  Austin Burt  Burkina Faso    Bana Village
# 316  AB0411-C           BF20-56  Austin Burt  Burkina Faso    Bana Village
# 317  AB0413-C           BF20-59  Austin Burt  Burkina Faso    Bana Village
# 342  AB0503-C            BF13-1  Austin Burt  Burkina Faso  Souroukoudinga
# 344  AB0505-C           BF13-13  Austin Burt  Burkina Faso  Souroukoudinga
# 345  AB0508-C           BF13-38  Austin Burt  Burkina Faso  Souroukoudinga
# 346  AB0509-C           BF24-55  Austin Burt  Burkina Faso  Souroukoudinga
# 347  AB0510-C           BF24-56  Austin Burt  Burkina Faso  Souroukoudinga
# 349  AB0523-C           BF24-26  Austin Burt  Burkina Faso  Souroukoudinga
# 363  AB0408-C           BF14-20  Austin Burt  Burkina Faso    Bana Village
#
#      year  month  latitude  longitude sex_call  ...    admin1_name admin1_iso  \
# 262  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 263  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 264  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 265  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 266  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 267  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 268  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 270  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 271  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 272  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 273  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 274  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 275  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 276  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 277  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 278  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 279  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 280  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 281  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 282  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 283  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 284  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 285  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 286  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 287  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 288  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 289  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 290  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 291  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 292  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 293  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 294  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 295  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 296  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 297  2014      7    11.233     -4.472        M  ...  Hauts-Bassins      BF-09
# 307  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 308  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 309  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 310  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 311  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 312  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 313  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 314  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 315  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 316  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 317  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
# 342  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 344  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 345  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 346  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 347  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 349  2014      7    11.238     -4.235        F  ...  Hauts-Bassins      BF-09
# 363  2014      7    11.233     -4.472        F  ...  Hauts-Bassins      BF-09
#
#      admin2_name     taxon  cohort_admin1_year  cohort_admin1_month  \
# 262        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 263        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 264        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 265        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 266        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 267        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 268        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 270        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 271        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 272        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 273        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 274        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 275        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 276        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 277        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 278        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 279        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 280        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 281        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 282        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 283        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 284        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 285        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 286        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 287        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 288        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 289        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 290        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 291        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 292        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 293        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 294        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 295        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 296        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 297        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 307        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 308        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 309        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 310        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 311        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 312        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 313        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 314        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 315        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 316        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 317        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 342        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 344        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 345        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 346        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 347        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 349        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
# 363        Houet  coluzzii     BF-09_colu_2014   BF-09_colu_2014_07
#
#     cohort_admin1_quarter     cohort_admin2_year       cohort_admin2_month  \
# 262    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 263    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 264    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 265    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 266    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 267    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 268    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 270    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 271    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 272    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 273    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 274    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 275    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 276    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 277    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 278    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 279    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 280    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 281    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 282    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 283    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 284    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 285    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 286    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 287    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 288    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 289    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 290    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 291    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 292    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 293    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 294    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 295    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 296    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 297    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 307    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 308    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 309    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 310    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 311    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 312    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 313    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 314    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 315    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 316    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 317    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 342    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 344    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 345    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 346    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 347    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 349    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
# 363    BF-09_colu_2014_Q3  BF-09_Houet_colu_2014  BF-09_Houet_colu_2014_07
#
#         cohort_admin2_quarter
# 262  BF-09_Houet_colu_2014_Q3
# 263  BF-09_Houet_colu_2014_Q3
# 264  BF-09_Houet_colu_2014_Q3
# 265  BF-09_Houet_colu_2014_Q3
# 266  BF-09_Houet_colu_2014_Q3
# 267  BF-09_Houet_colu_2014_Q3
# 268  BF-09_Houet_colu_2014_Q3
# 270  BF-09_Houet_colu_2014_Q3
# 271  BF-09_Houet_colu_2014_Q3
# 272  BF-09_Houet_colu_2014_Q3
# 273  BF-09_Houet_colu_2014_Q3
# 274  BF-09_Houet_colu_2014_Q3
# 275  BF-09_Houet_colu_2014_Q3
# 276  BF-09_Houet_colu_2014_Q3
# 277  BF-09_Houet_colu_2014_Q3
# 278  BF-09_Houet_colu_2014_Q3
# 279  BF-09_Houet_colu_2014_Q3
# 280  BF-09_Houet_colu_2014_Q3
# 281  BF-09_Houet_colu_2014_Q3
# 282  BF-09_Houet_colu_2014_Q3
# 283  BF-09_Houet_colu_2014_Q3
# 284  BF-09_Houet_colu_2014_Q3
# 285  BF-09_Houet_colu_2014_Q3
# 286  BF-09_Houet_colu_2014_Q3
# 287  BF-09_Houet_colu_2014_Q3
# 288  BF-09_Houet_colu_2014_Q3
# 289  BF-09_Houet_colu_2014_Q3
# 290  BF-09_Houet_colu_2014_Q3
# 291  BF-09_Houet_colu_2014_Q3
# 292  BF-09_Houet_colu_2014_Q3
# 293  BF-09_Houet_colu_2014_Q3
# 294  BF-09_Houet_colu_2014_Q3
# 295  BF-09_Houet_colu_2014_Q3
# 296  BF-09_Houet_colu_2014_Q3
# 297  BF-09_Houet_colu_2014_Q3
# 307  BF-09_Houet_colu_2014_Q3
# 308  BF-09_Houet_colu_2014_Q3
# 309  BF-09_Houet_colu_2014_Q3
# 310  BF-09_Houet_colu_2014_Q3
# 311  BF-09_Houet_colu_2014_Q3
# 312  BF-09_Houet_colu_2014_Q3
# 313  BF-09_Houet_colu_2014_Q3
# 314  BF-09_Houet_colu_2014_Q3
# 315  BF-09_Houet_colu_2014_Q3
# 316  BF-09_Houet_colu_2014_Q3
# 317  BF-09_Houet_colu_2014_Q3
# 342  BF-09_Houet_colu_2014_Q3
# 344  BF-09_Houet_colu_2014_Q3
# 345  BF-09_Houet_colu_2014_Q3
# 346  BF-09_Houet_colu_2014_Q3
# 347  BF-09_Houet_colu_2014_Q3
# 349  BF-09_Houet_colu_2014_Q3
# 363  BF-09_Houet_colu_2014_Q3
#
# [53 rows x 30 columns]

# %% [markdown]
# ### Part 4 - SNPs that change the protein sequence:

# %%
snp_freqs_df['effect'].value_counts()
# Out:
# INTRONIC                 9467
# NON_SYNONYMOUS_CODING     121
# SYNONYMOUS_CODING          56
# STOP_GAINED                14
# SPLICE_REGION               9
# SPLICE_CORE                 8
# Name: effect, dtype: int64

# %%
# SNPs that change proteins
SNP_effect_df = snp_freqs_df.query("effect == 'NON_SYNONYMOUS_CODING'")
SNP_effect_df
# Out:
#                                                  pass_gamb_colu_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                      True
#        2362019  G          T          G54C                      True
#        2362023  C          T          P55L                      True
#        2362034  C          A          P59T                      True
#        2362077  G          A          G73D                      True
# ...                                                              ...
#        2431328  C          G          A2023G                    True
#        2431371  C          G          S2037R                   False
#        2431417  A          G          I2053V                    True
#        2431424  G          T          G2055V                    True
#        2431613  T          C          V2118A                    True
#
#                                                  pass_gamb_colu  pass_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                 True       True
#        2362019  G          T          G54C                 True       True
#        2362023  C          T          P55L                 True       True
#        2362034  C          A          P59T                 True       True
#        2362077  G          A          G73D                 True       True
# ...                                                         ...        ...
#        2431328  C          G          A2023G               True       True
#        2431371  C          G          S2037R               True      False
#        2431417  A          G          I2053V               True       True
#        2431424  G          T          G2055V               True       True
#        2431613  T          C          V2118A               True       True
#
#                                                  frq_BF-07_gamb_2004  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2362019  G          T          G54C                  0.000000
#        2362023  C          T          P55L                  0.000000
#        2362034  C          A          P59T                  0.000000
#        2362077  G          A          G73D                  0.000000
# ...                                                              ...
#        2431328  C          G          A2023G                0.038462
#        2431371  C          G          S2037R                0.000000
#        2431417  A          G          I2053V                0.038462
#        2431424  G          T          G2055V                0.000000
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.006098
#        2362019  G          T          G54C                  0.018293
#        2362023  C          T          P55L                  0.000000
#        2362034  C          A          P59T                  0.000000
#        2362077  G          A          G73D                  0.006098
# ...                                                              ...
#        2431328  C          G          A2023G                0.000000
#        2431371  C          G          S2037R                0.000000
#        2431417  A          G          I2053V                0.000000
#        2431424  G          T          G2055V                0.000000
#        2431613  T          C          V2118A                0.000000
#
#                                                  frq_BF-09_colu_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                       0.0
#        2362019  G          T          G54C                       0.0
#        2362023  C          T          P55L                       0.0
#        2362034  C          A          P59T                       0.0
#        2362077  G          A          G73D                       0.0
# ...                                                              ...
#        2431328  C          G          A2023G                     0.0
#        2431371  C          G          S2037R                     0.0
#        2431417  A          G          I2053V                     0.0
#        2431424  G          T          G2055V                     0.0
#        2431613  T          C          V2118A                     0.0
#
#                                                  frq_BF-09_gamb_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2362019  G          T          G54C                  0.000000
#        2362023  C          T          P55L                  0.005051
#        2362034  C          A          P59T                  0.000000
#        2362077  G          A          G73D                  0.000000
# ...                                                              ...
#        2431328  C          G          A2023G                0.000000
#        2431371  C          G          S2037R                0.005051
#        2431417  A          G          I2053V                0.000000
#        2431424  G          T          G2055V                0.005051
#        2431613  T          C          V2118A                0.005051
#
#                                                  frq_BF-09_gamb_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V                  0.000000
#        2362019  G          T          G54C                  0.010870
#        2362023  C          T          P55L                  0.010870
#        2362034  C          A          P59T                  0.021739
#        2362077  G          A          G73D                  0.000000
# ...                                                              ...
#        2431328  C          G          A2023G                0.000000
#        2431371  C          G          S2037R                0.000000
#        2431417  A          G          I2053V                0.000000
#        2431424  G          T          G2055V                0.000000
#        2431613  T          C          V2118A                0.000000
#
#                                                    max_af     transcript  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       0.006098  AGAP004707-RD
#        2362019  G          T          G54C       0.018293  AGAP004707-RD
#        2362023  C          T          P55L       0.010870  AGAP004707-RD
#        2362034  C          A          P59T       0.021739  AGAP004707-RD
#        2362077  G          A          G73D       0.006098  AGAP004707-RD
# ...                                                   ...            ...
#        2431328  C          G          A2023G     0.038462  AGAP004707-RD
#        2431371  C          G          S2037R     0.005051  AGAP004707-RD
#        2431417  A          G          I2053V     0.038462  AGAP004707-RD
#        2431424  G          T          G2055V     0.005051  AGAP004707-RD
#        2431613  T          C          V2118A     0.005051  AGAP004707-RD
#
#                                                                 effect  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       NON_SYNONYMOUS_CODING
#        2362019  G          T          G54C       NON_SYNONYMOUS_CODING
#        2362023  C          T          P55L       NON_SYNONYMOUS_CODING
#        2362034  C          A          P59T       NON_SYNONYMOUS_CODING
#        2362077  G          A          G73D       NON_SYNONYMOUS_CODING
# ...                                                                ...
#        2431328  C          G          A2023G     NON_SYNONYMOUS_CODING
#        2431371  C          G          S2037R     NON_SYNONYMOUS_CODING
#        2431417  A          G          I2053V     NON_SYNONYMOUS_CODING
#        2431424  G          T          G2055V     NON_SYNONYMOUS_CODING
#        2431613  T          C          V2118A     NON_SYNONYMOUS_CODING
#
#                                                    impact ref_codon alt_codon  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V       MODERATE       gCa       gTa
#        2362019  G          T          G54C       MODERATE       Ggt       Tgt
#        2362023  C          T          P55L       MODERATE       cCc       cTc
#        2362034  C          A          P59T       MODERATE       Cct       Act
#        2362077  G          A          G73D       MODERATE       gGc       gAc
# ...                                                   ...       ...       ...
#        2431328  C          G          A2023G     MODERATE       gCa       gGa
#        2431371  C          G          S2037R     MODERATE       agC       agG
#        2431417  A          G          I2053V     MODERATE       Att       Gtt
#        2431424  G          T          G2055V     MODERATE       gGc       gTc
#        2431613  T          C          V2118A     MODERATE       gTc       gCc
#
#                                                  aa_pos ref_aa alt_aa  \
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V         32.0      A      V
#        2362019  G          T          G54C         54.0      G      C
#        2362023  C          T          P55L         55.0      P      L
#        2362034  C          A          P59T         59.0      P      T
#        2362077  G          A          G73D         73.0      G      D
# ...                                                 ...    ...    ...
#        2431328  C          G          A2023G     2023.0      A      G
#        2431371  C          G          S2037R     2037.0      S      R
#        2431417  A          G          I2053V     2053.0      I      V
#        2431424  G          T          G2055V     2055.0      G      V
#        2431613  T          C          V2118A     2118.0      V      A
#
#                                                                      label
# contig position ref_allele alt_allele aa_change
# 2L     2358252  C          T          A32V         2L:2,358,252 C>T (A32V)
#        2362019  G          T          G54C         2L:2,362,019 G>T (G54C)
#        2362023  C          T          P55L         2L:2,362,023 C>T (P55L)
#        2362034  C          A          P59T         2L:2,362,034 C>A (P59T)
#        2362077  G          A          G73D         2L:2,362,077 G>A (G73D)
# ...                                                                    ...
#        2431328  C          G          A2023G     2L:2,431,328 C>G (A2023G)
#        2431371  C          G          S2037R     2L:2,431,371 C>G (S2037R)
#        2431417  A          G          I2053V     2L:2,431,417 A>G (I2053V)
#        2431424  G          T          G2055V     2L:2,431,424 G>T (G2055V)
#        2431613  T          C          V2118A     2L:2,431,613 T>C (V2118A)
#
# [121 rows x 18 columns]

# %% [markdown]
# ### Part 5 - SNPs that change protein sequences and have maf >5%

# %%
# SNPs that change protein sequence and have >5% frequency
SNP_effect5_df = snp_freqs_df.query("effect =='NON_SYNONYMOUS_CODING' and max_af >0.05" )
SNP_effect5_df
# Out:
#                                                  pass_gamb_colu_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                     True
#                            T          V402L                     True
#        2416980  C          T          T791M                     True
#        2422652  A          T          L995F                     True
#        2429617  T          C          I1527T                    True
#        2429745  A          T          N1570Y                    True
#        2429897  A          G          E1597G                    True
#        2429915  A          C          K1603T                    True
#        2430424  G          T          A1746S                   False
#        2430863  T          C          I1868T                    True
#        2430880  C          T          P1874S                    True
#        2430881  C          T          P1874L                    True
#        2431061  C          T          A1934V                    True
#
#                                                  pass_gamb_colu  pass_arab  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                True       True
#                            T          V402L                True       True
#        2416980  C          T          T791M                True       True
#        2422652  A          T          L995F                True       True
#        2429617  T          C          I1527T               True       True
#        2429745  A          T          N1570Y               True       True
#        2429897  A          G          E1597G               True       True
#        2429915  A          C          K1603T               True       True
#        2430424  G          T          A1746S               True      False
#        2430863  T          C          I1868T               True       True
#        2430880  C          T          P1874S               True       True
#        2430881  C          T          P1874L               True       True
#        2431061  C          T          A1934V               True       True
#
#                                                  frq_BF-07_gamb_2004  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                 0.000000
#                            T          V402L                 0.000000
#        2416980  C          T          T791M                 0.000000
#        2422652  A          T          L995F                 0.076923
#        2429617  T          C          I1527T                0.000000
#        2429745  A          T          N1570Y                0.038462
#        2429897  A          G          E1597G                0.000000
#        2429915  A          C          K1603T                0.000000
#        2430424  G          T          A1746S                0.000000
#        2430863  T          C          I1868T                0.000000
#        2430880  C          T          P1874S                0.000000
#        2430881  C          T          P1874L                0.000000
#        2431061  C          T          A1934V                0.000000
#
#                                                  frq_BF-09_colu_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                 0.067073
#                            T          V402L                 0.054878
#        2416980  C          T          T791M                 0.018293
#        2422652  A          T          L995F                 0.865854
#        2429617  T          C          I1527T                0.121951
#        2429745  A          T          N1570Y                0.250000
#        2429897  A          G          E1597G                0.000000
#        2429915  A          C          K1603T                0.054878
#        2430424  G          T          A1746S                0.000000
#        2430863  T          C          I1868T                0.000000
#        2430880  C          T          P1874S                0.213415
#        2430881  C          T          P1874L                0.073171
#        2431061  C          T          A1934V                0.121951
#
#                                                  frq_BF-09_colu_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                 0.028302
#                            T          V402L                 0.084906
#        2416980  C          T          T791M                 0.000000
#        2422652  A          T          L995F                 0.886792
#        2429617  T          C          I1527T                0.113208
#        2429745  A          T          N1570Y                0.320755
#        2429897  A          G          E1597G                0.000000
#        2429915  A          C          K1603T                0.056604
#        2430424  G          T          A1746S                0.000000
#        2430863  T          C          I1868T                0.000000
#        2430880  C          T          P1874S                0.169811
#        2430881  C          T          P1874L                0.056604
#        2431061  C          T          A1934V                0.132075
#
#                                                  frq_BF-09_gamb_2012  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                 0.000000
#                            T          V402L                 0.000000
#        2416980  C          T          T791M                 0.161616
#        2422652  A          T          L995F                 1.000000
#        2429617  T          C          I1527T                0.000000
#        2429745  A          T          N1570Y                0.212121
#        2429897  A          G          E1597G                0.065657
#        2429915  A          C          K1603T                0.000000
#        2430424  G          T          A1746S                0.151515
#        2430863  T          C          I1868T                0.247475
#        2430880  C          T          P1874S                0.000000
#        2430881  C          T          P1874L                0.222222
#        2431061  C          T          A1934V                0.000000
#
#                                                  frq_BF-09_gamb_2014  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L                 0.000000
#                            T          V402L                 0.000000
#        2416980  C          T          T791M                 0.239130
#        2422652  A          T          L995F                 1.000000
#        2429617  T          C          I1527T                0.000000
#        2429745  A          T          N1570Y                0.141304
#        2429897  A          G          E1597G                0.032609
#        2429915  A          C          K1603T                0.000000
#        2430424  G          T          A1746S                0.239130
#        2430863  T          C          I1868T                0.206522
#        2430880  C          T          P1874S                0.000000
#        2430881  C          T          P1874L                0.260870
#        2431061  C          T          A1934V                0.000000
#
#                                                    max_af     transcript  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L      0.067073  AGAP004707-RD
#                            T          V402L      0.084906  AGAP004707-RD
#        2416980  C          T          T791M      0.239130  AGAP004707-RD
#        2422652  A          T          L995F      1.000000  AGAP004707-RD
#        2429617  T          C          I1527T     0.121951  AGAP004707-RD
#        2429745  A          T          N1570Y     0.320755  AGAP004707-RD
#        2429897  A          G          E1597G     0.065657  AGAP004707-RD
#        2429915  A          C          K1603T     0.056604  AGAP004707-RD
#        2430424  G          T          A1746S     0.239130  AGAP004707-RD
#        2430863  T          C          I1868T     0.247475  AGAP004707-RD
#        2430880  C          T          P1874S     0.213415  AGAP004707-RD
#        2430881  C          T          P1874L     0.260870  AGAP004707-RD
#        2431061  C          T          A1934V     0.132075  AGAP004707-RD
#
#                                                                 effect  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L      NON_SYNONYMOUS_CODING
#                            T          V402L      NON_SYNONYMOUS_CODING
#        2416980  C          T          T791M      NON_SYNONYMOUS_CODING
#        2422652  A          T          L995F      NON_SYNONYMOUS_CODING
#        2429617  T          C          I1527T     NON_SYNONYMOUS_CODING
#        2429745  A          T          N1570Y     NON_SYNONYMOUS_CODING
#        2429897  A          G          E1597G     NON_SYNONYMOUS_CODING
#        2429915  A          C          K1603T     NON_SYNONYMOUS_CODING
#        2430424  G          T          A1746S     NON_SYNONYMOUS_CODING
#        2430863  T          C          I1868T     NON_SYNONYMOUS_CODING
#        2430880  C          T          P1874S     NON_SYNONYMOUS_CODING
#        2430881  C          T          P1874L     NON_SYNONYMOUS_CODING
#        2431061  C          T          A1934V     NON_SYNONYMOUS_CODING
#
#                                                    impact ref_codon alt_codon  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L      MODERATE       Gta       Cta
#                            T          V402L      MODERATE       Gta       Tta
#        2416980  C          T          T791M      MODERATE       aCg       aTg
#        2422652  A          T          L995F      MODERATE       ttA       ttT
#        2429617  T          C          I1527T     MODERATE       aTt       aCt
#        2429745  A          T          N1570Y     MODERATE       Aat       Tat
#        2429897  A          G          E1597G     MODERATE       gAa       gGa
#        2429915  A          C          K1603T     MODERATE       aAg       aCg
#        2430424  G          T          A1746S     MODERATE       Gcc       Tcc
#        2430863  T          C          I1868T     MODERATE       aTa       aCa
#        2430880  C          T          P1874S     MODERATE       Cct       Tct
#        2430881  C          T          P1874L     MODERATE       cCt       cTt
#        2431061  C          T          A1934V     MODERATE       gCt       gTt
#
#                                                  aa_pos ref_aa alt_aa  \
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L       402.0      V      L
#                            T          V402L       402.0      V      L
#        2416980  C          T          T791M       791.0      T      M
#        2422652  A          T          L995F       995.0      L      F
#        2429617  T          C          I1527T     1527.0      I      T
#        2429745  A          T          N1570Y     1570.0      N      Y
#        2429897  A          G          E1597G     1597.0      E      G
#        2429915  A          C          K1603T     1603.0      K      T
#        2430424  G          T          A1746S     1746.0      A      S
#        2430863  T          C          I1868T     1868.0      I      T
#        2430880  C          T          P1874S     1874.0      P      S
#        2430881  C          T          P1874L     1874.0      P      L
#        2431061  C          T          A1934V     1934.0      A      V
#
#                                                                      label
# contig position ref_allele alt_allele aa_change
# 2L     2391228  G          C          V402L       2L:2,391,228 G>C (V402L)
#                            T          V402L       2L:2,391,228 G>T (V402L)
#        2416980  C          T          T791M       2L:2,416,980 C>T (T791M)
#        2422652  A          T          L995F       2L:2,422,652 A>T (L995F)
#        2429617  T          C          I1527T     2L:2,429,617 T>C (I1527T)
#        2429745  A          T          N1570Y     2L:2,429,745 A>T (N1570Y)
#        2429897  A          G          E1597G     2L:2,429,897 A>G (E1597G)
#        2429915  A          C          K1603T     2L:2,429,915 A>C (K1603T)
#        2430424  G          T          A1746S     2L:2,430,424 G>T (A1746S)
#        2430863  T          C          I1868T     2L:2,430,863 T>C (I1868T)
#        2430880  C          T          P1874S     2L:2,430,880 C>T (P1874S)
#        2430881  C          T          P1874L     2L:2,430,881 C>T (P1874L)
#        2431061  C          T          A1934V     2L:2,431,061 C>T (A1934V)

# %% [markdown]
# ## Input/output
#
# We saw at the beginning of this module how to read in data from a file. Let's look finally at how to write data out to a file.
#
# To write a DataFrame out to a CSV file, use the [to_csv()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html) function. E.g., let's write out the book characters DataFrame to a CSV file.

# %%
df_hitchhikers.to_csv("hitchhikers.csv")

# %% [markdown]
# You can download this file to your local computer by opening the file browser tab to the left in colab.
#
# There are several other file formats you can write to. E.g., you could write to an Excel file. Here, we use the

# %%
df_hitchhikers.to_excel("hitchhikers.xlsx")

# %% [markdown]
# Any of the DataFrames we created in this module could be written out in the same way. E.g., we could write a DataFrame that we obtained by querying the book characters for only humans.

# %%
df_human_hitchhikers.to_excel("hh_human.xlsx")

# %% [markdown]
# ## **Exercise 9 (English)**
#
# * Write the `df_samples` DataFrame out to an Excel file.
# * Query the `df_samples` DataFrame to select only mosquitoes from Burkina Faso, then write the resulting DataFrame out to a CSV file.

# %% [markdown]
# ### Part 1 - `df_samples` dataframe to excel

# %%
# write df_samples to excel
df_samples.to_excel('mosquito_data.xlsx')

# %% [markdown]
# ### Part 2 - Burkina Faso mosquitoes  to csv

# %%
# Burkina Faso mosquitos and write as csv
Burkina_mosq_df = df_samples.query("country == 'Burkina Faso'")
# write to csv
Burkina_mosq_df.to_csv('Burkina Faso_mosquitoes.csv')

# %% [markdown]
# Alternatively:

# %%
df_samples.query("country == 'Burkina Faso'").to_csv('Burkina_mosquitoes.csv')

# %% [markdown]
# ## Topics not covered here
#
# Please note that this module has only covered a few of the many features that pandas supports. Here are a few of the features that we have not covered, but which you might like to learn more about through other online tutorials.
#
# * Grouping and aggregation
# * Pivot tables
# * Joining and merging
# * Concatenating
# * Advanced indexing (multi-level indexes; Boolean indexing; ...)
# * Modifying data
# * Apply
# * Missing data
# * Time series
# * Plotting
# * Text
# * ...

# %% [markdown]
# ## Further reading
#
# Here are a few links to online resources providing further information about pandas for new users.
#
# * [pandas getting started](https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html)
# * [pandas user guide](https://pandas.pydata.org/docs/user_guide/index.html) (in particular see [10 minutes to pandas](https://pandas.pydata.org/docs/user_guide/10min.html))
# * [pandas community tutorials](https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html)
